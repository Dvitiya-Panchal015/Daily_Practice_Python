# %% [markdown]
# # Pandas Challenges (Based on Your Notebook)

# %%
#1. Challenge 1 – Complete Data Cleaning
# Your manager gives you a messy dataset.
# Perform all of the following:
# • Load the dataset.
# • Display dataset information.
# • Find missing values.
# • Remove duplicate rows.
# • Fill missing values:
# o Age → median
# o Balance → mean
# • Rename:
# o Target → CustomerStatus
# o AnnualIncome → Income
# • Display the first 15 rows.
# Methods expected:
# read_csv()
# info()
# isnull()
# drop_duplicates()
# median()
# mean()
# fillna()
# rename()
# head()

import pandas as pd
df = pd.read_csv("C:\\Users\\Shree\\Downloads\\Task_dataset.csv")
df
print(df.info())
print(df.isnull().sum())
print(df.drop_duplicates())
df["Age"].fillna(df["Age"].median())
df["Balance"].fillna(df["Balance"].mean())
df.rename(columns = { "Target":"CustomerStatus","AnnualIncome":"Income"},inplace = True)

print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    CustomerID   1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB
# None
#  CustomerID      0
# Age             50
# AnnualIncome    53
# Spending         0
# CreditScore      0
# Balance         51
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# ...

# %%
#2. Banking Report
# The bank wants a numeric report.
# Tasks
# • Select only numeric columns.

# • Display summary statistics.
# • Convert Age and CreditScore to float.
# • Display information again.


numeric_df = df.select_dtypes(include=["number"])
print(numeric_df.describe())
df["Age"] = df["Age"].astype(float)
df["CreditScore"] = df["CreditScore"].astype(float)
df.info()
# Out:
#         CustomerID          Age         Income      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     969.000000  1020.000000
# mean    97523.535666     5.261765
# std     55796.562543     3.185330
# min       547.600000     0.000000
# 25%     50077.860000     2.000000
# 50%     95100.060000     5.000000
# 75%    143947.810000     8.000000
# ...

# %%
#3. Duplicate Investigation
# Find duplicate customer
# Then
# • Count duplicate rows.
# • Remove duplicates.
# • Print information before and after removing duplicates.
# • Show the last 20 rows.

print(df.drop_duplicates())
count = df.duplicated().sum()
count
df= df.drop_duplicates()
df
df.tail(20)
# Out:
#       CustomerID    Age    Income  Spending  CreditScore    Balance  Tenure  \
# 0           10001  58.0   49184.0      2139        581.0        NaN       2
# 1           10002  65.0  162964.0      6197        732.0    6356.54       1
# 2           10003  56.0   26956.0     37281        503.0  143203.92       8
# 3           10004  55.0   92926.0       925        463.0  139627.88       5
# 4           10005  66.0  108236.0      7198        394.0   75985.46       5
# ..            ...   ...       ...       ...          ...        ...     ...
# 995         10996  34.0   81731.0     40980        761.0  181465.65       5
# 996         10997  47.0   42475.0      1176        780.0   26640.99       5
# 997         10998  31.0  120531.0     46929        733.0  147220.82       4
# 998         10999  21.0   33661.0     22314        540.0   94186.48       5
# 999         11000  63.0   31930.0       851        559.0  100908.40       6
#
#     Geography  Gender    Segment CustomerStatus
# ...

# %%
#4. HR Department
# HR wants better column names.
# Rename
# CustomerID → Employee_ID
# Age → EmployeeAge
# Gender → EmployeeGender
# AnnualIncome → Salary
# Target → PromotionStatus
# Then
# • Add prefix
#HR_
# t o every column.
# Display 10 random records.

df = df.rename(columns= {"CustomerID":"Employee_ID","Age":"EmployeeAge","Gender":"EmployeeGender","Anuualincome":"Salary","Target":"PromotionStatus"})
df
df.add_prefix("HR_")
df.sample(10)
# Out:
#       CustomerID   EmployeeAge  AnnualIncome  Spending  CreditScore  \
# 942         10943         60.0      178116.0     27005          796
# 361         10362         19.0      109935.0     42965          411
# 214         10215         58.0      155102.0     38186          547
# 18          10019         24.0      183918.0     20058          819
# 445         10446         54.0       69344.0     32758          855
# 330         10331         20.0       80231.0     14355          880
# 698         10699         46.0      112359.0     21153          863
# 649         10650          NaN       94608.0     23772          632
# 945         10946         27.0       99364.0     41261          398
# 375         10376         50.0       49677.0     38033          416
#
#        Balance  Tenure Geography EmployeeGender    Segment PromotionStatus
# 942  102282.90       2    Canada           Male     Retail            Stay
# ...

# %%
#5. Finance Cleaning
# Finance department reports missing values.

# Tasks
# Fill
# AnnualIncome → Median
# Balance → Mean
# Age → Median

df2 = pd.read_csv("C:\\Users\\Shree\\Downloads\\Task_dataset.csv")
df2
print(df2.isnull().sum())
print(df2["AnnualIncome"].fillna(df2["AnnualIncome"].median()))
print(df2["Balance"].fillna(df2["Balance"].mean()))
print(df2["Age"].fillna(df2["Age"].mean()))
print(df.describe())
# Out:
#  CustomerID      0
# Age             50
# AnnualIncome    53
# Spending         0
# CreditScore      0
# Balance         51
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# dtype: int64
# 0        49184.0
# 1       162964.0
# 2        26956.0
# 3        92926.0
# 4       108236.0
#           ...
# 1015    173620.0
# 1016     54490.0
# 1017     82062.0
# 1018    112358.0
# 1019     97504.0
# Name: AnnualIncome, Length: 1020, dtype: float64
# 0        97523.535666
# 1         6356.540000
# 2       143203.920000
# 3       139627.880000
# 4        75985.460000
#             ...
# 1015     60353.030000
# 1016    124512.070000
# 1017     53850.090000
# 1018    138100.050000
# 1019     97523.535666
# Name: Balance, Length: 1020, dtype: float64
# 0       58.0
# 1       65.0
# 2       56.0
# 3       55.0
# 4       66.0
#         ...
# 1015    43.0
# 1016    25.0
# 1017    49.0
# 1018    38.0
# 1019    62.0
# ...

# %%
#6.– Data Type Audit
# The company says
# Age and AnnualIncome are stored incorrectly.
# Tasks
# Convert
# Age → int
# AnnualIncome → float
# Balance → float
import pandas as pd
df7 = pd.read_csv("C:\\Users\\Shree\\Downloads\\Task_dataset.csv")
df7

df7["Age"] = df7["Age"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[186], line 13
#      10 df7 = pd.read_csv("C:\\Users\\Shree\\Downloads\\Task_dataset.csv")
#      11 df7
# ---> 13 df7["Age"] = df7["Age"].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df["AnnualIncome"] = df["AnnualIncome"].astype(float)
df["AnnualIncome"]
# Out:
# 0        49184.0
# 1       162964.0
# 2        26956.0
# 3        92926.0
# 4       108236.0
#           ...
# 1015    173620.0
# 1016     54490.0
# 1017     82062.0
# 1018         NaN
# 1019     97504.0
# Name: AnnualIncome, Length: 1020, dtype: float64

# %%
df["Balance"] = df["Balance"].astype(float)
df["Balance"]
# Out:
# 0             NaN
# 1         6356.54
# 2       143203.92
# 3       139627.88
# 4        75985.46
#           ...
# 1015     60353.03
# 1016    124512.07
# 1017     53850.09
# 1018    138100.05
# 1019          NaN
# Name: Balance, Length: 1020, dtype: float64

# %%
#7. – Customer Analytics
# Create a new DataFrame that
# • removes Segment
# • removes Geography
# • removes duplicate rows
#Display
# •  first 10 rows
# • dataset information
# • statistical summary


print(df2.drop_duplicates())
print(df2.head(10))
print(df2.info())
print(df2.describe())
# Out:
#       CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0           10001  58.0       49184.0      2139          581        NaN
# 1           10002  65.0      162964.0      6197          732    6356.54
# 2           10003  56.0       26956.0     37281          503  143203.92
# 3           10004  55.0       92926.0       925          463  139627.88
# 4           10005  66.0      108236.0      7198          394   75985.46
# ..            ...   ...           ...       ...          ...        ...
# 995         10996  34.0       81731.0     40980          761  181465.65
# 996         10997  47.0       42475.0      1176          780   26640.99
# 997         10998  31.0      120531.0     46929          733  147220.82
# 998         10999  21.0       33661.0     22314          540   94186.48
# 999         11000  63.0       31930.0       851          559  100908.40
#
#      Tenure Geography  Gender    Segment Target
# 0         2    France    Male        SME   Stay
# ...

# %%
#8. – ML Dataset Preparation
# Prepare a machine learning dataset.
# Perform
# • Remove duplicates
# • Remove CustomerID
# • Remove Segment
# • Fill missing values
# • Rename Target to Output
#Finally
#Display
# head()
# info()
# describe()
# value_counts(Output)

import pandas as pd
df2 = pd.read_csv("C:\\Users\\Shree\\Downloads\\Task_dataset.csv")
df2
df2.drop_duplicates()
df2['Age'].fillna('unknown')
df2
df2.rename = df2.rename(columns = {"Target":"Output"})
df2.rename
df2.head()
df2.info()
df2.describe()
df2.value_counts("Target")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    CustomerID   1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB
# Target
# Churn    515
# Stay     505
# Name: count, dtype: int64

# %%
#9. Column Transformation
# Create these new columns
# NetWorth = Balance + AnnualIncome
# AgeAfterRetirement = Age + 20
# DoubleCreditScore = CreditScore * 2
# IncomePerMonth = AnnualIncome / 12
# Then
# Display first 15 rows.

df2["Networth"] = df2["Balance"] + df2["AnnualIncome"]
df2["Networth"]
df2["AgeAfterRetirement"] = df2["Age"] + 20
df2["AgeAfterRetirement"]
df2["DoubleCreditScore"] = df2["CreditScore"] * 2
df2["DoubleCreditScore"]

df2["IncomePerMonth"] = df2["AnnualIncome"] / 12
df2["IncomePerMonth"]

print(df2.head(20))
# Out:
#      CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# 5          10006  69.0       31390.0     48323          770  107245.62
# 6          10007  58.0      182141.0     24200          891   38457.72
# 7          10008  67.0       95861.0      5729          538  173296.73
# 8          10009  41.0       62638.0     24760          663   41901.41
# 9          10010  22.0      179680.0     42113          475  106827.98
# 10         10011   NaN      187772.0     45599          870   43923.03
# 11         10012  69.0      102694.0     26790          574   13237.72
# ...

# %%
#10. – Company Report
# Display
# • first five rows
# • last five rows
# • ten random rows
# • dataset information
# •  descriptive statistics
# Finally rename
# Target → Customer_Status

print(df2.head(5))
print(df2.tail(5))
df2.sample(10)
df2.info()
df2.describe()
# Out:
#     CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target   Networth  AgeAfterRetirement  \
# 0    France   Male        SME   Stay        NaN                78.0
# 1       USA   Male        SME  Churn  169320.54                85.0
# 2    Canada   Male  Corporate   Stay  170159.92                76.0
# 3       NaN   Male     Retail  Churn  232553.88                75.0
# 4        UK  Other  Corporate  Churn  184221.46                86.0
#
#    DoubleCreditScore  IncomePerMonth
# 0               1162     4098.666667
# ...

# %%
df.rename(columns = {"Target":"Customer_Status"})
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Customer_Status
# ...

# %%
#11. – Missing Value Report
# Create a report showing
#  • Total missing values
# • Numerical columns
# • Mean of Balance
# • Median of Age
# • Fill missing values
# • Display information again

df.isnull().sum()
# Out:
#  CustomerID      0
# Age             50
# AnnualIncome    53
# Spending         0
# CreditScore      0
# Balance         51
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# dtype: int64

# %%
df.isna().sum()
# Out:
#  CustomerID         0
# Age                50
# AnnualIncome       53
# Spending            0
# CreditScore         0
# Balance            51
# Tenure              0
# SeniorCitizen      50
# HighCreditScore     0
# dtype: int64

# %%
int_column=df.select_dtypes(include = ["int64"]).columns
len(int_column)
# Out:
# 4

# %%
print(df2["Balance"].fillna(df2["Balance"].mean()))
# Out:
# 0        97523.535666
# 1         6356.540000
# 2       143203.920000
# 3       139627.880000
# 4        75985.460000
#             ...
# 1015     60353.030000
# 1016    124512.070000
# 1017     53850.090000
# 1018    138100.050000
# 1019     97523.535666
# Name: Balance, Length: 1020, dtype: float64

# %%
df["Age"] = df["Age"].fillna("Age")
df["Age"]
# Out:
# 0       58.0
# 1       65.0
# 2       56.0
# 3       55.0
# 4       66.0
#         ...
# 1015    43.0
# 1016    25.0
# 1017    49.0
# 1018    38.0
# 1019    62.0
# Name: Age, Length: 1020, dtype: object

# %%
df['Age'].fillna('unknown',inplace = True)
df
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    CustomerID   1020 non-null   int64
#  1   Age           1020 non-null   object
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 87.8+ KB

# %%
#12. Customer Classification
# Count
# Stay

# Churn
# Then
# Rename
# Target → Customer_Class
# Convert it into string.

df.rename(columns = {"Target":"Customer_class"})
df["Age"] = df["Age"].astype(str)
df["Age"]
# Out:
# 0       58.0
# 1       65.0
# 2       56.0
# 3       55.0
# 4       66.0
#         ...
# 1015    43.0
# 1016    25.0
# 1017    49.0
# 1018    38.0
# 1019    62.0
# Name: Age, Length: 1020, dtype: object

# %%
#13. Rename
# Balance → AccountBalance
# AnnualIncome → Salary
# CreditScore → Score
# Add prefix
# Sales_
# Then
# Display
# sample(20)

df.rename(columns = {"Balance":"AccountBalance","AnnualIncome":"Salary","CreditScore":"Score"})
# Out:
#        CustomerID    Age    Salary  Spending  Score  AccountBalance  Tenure  \
# 0            10001  58.0   49184.0      2139    581             NaN       2
# 1            10002  65.0  162964.0      6197    732         6356.54       1
# 2            10003  56.0   26956.0     37281    503       143203.92       8
# 3            10004  55.0   92926.0       925    463       139627.88       5
# 4            10005  66.0  108236.0      7198    394        75985.46       5
# ...            ...   ...       ...       ...    ...             ...     ...
# 1015         10450  43.0  173620.0      7121    644        60353.03       2
# 1016         10753  25.0   54490.0     13794    303       124512.07       4
# 1017         10810  49.0   82062.0     47170    813        53850.09       8
# 1018         10267  38.0       NaN     10424    722       138100.05       6
# 1019         10059  62.0   97504.0     36833    430             NaN      10
#
#      Geography  Gender    Segment Target
# ...

# %%
df.add_prefix("Sales_")
# Out:
#       Sales_ CustomerID  Sales_Age  Sales_AnnualIncome  Sales_Spending  \
# 0                  10001      58.0             49184.0            2139
# 1                  10002      65.0            162964.0            6197
# 2                  10003      56.0             26956.0           37281
# 3                  10004      55.0             92926.0             925
# 4                  10005      66.0            108236.0            7198
# ...                  ...       ...                 ...             ...
# 1015               10450      43.0            173620.0            7121
# 1016               10753      25.0             54490.0           13794
# 1017               10810      49.0             82062.0           47170
# 1018               10267      38.0                 NaN           10424
# 1019               10059      62.0             97504.0           36833
#
#       Sales_CreditScore  Sales_Balance  Sales_Tenure Sales_Geography  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    CustomerID   1020 non-null   int64
#  1   Age           1020 non-null   object
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 87.8+ KB

# %%
df.sample(20)
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 1007         10756  53.0       74430.0      3705          489   29651.23
# 235          10236  63.0      136683.0      6253          627  133567.96
# 529          10530  64.0      168114.0     15179          646  103819.94
# 678          10679  68.0      144589.0     45615          458   74279.73
# 374          10375  32.0      160930.0     19418          472  156148.04
# 429          10430  37.0      178152.0      3143          520  167184.95
# 27           10028  24.0      192748.0     28749          662   84715.72
# 85           10086  45.0      193413.0     24785          370  101192.16
# 986          10987  30.0      184704.0     20524          621  115161.87
# 58           10059  62.0       97504.0     36833          430        NaN
# 430          10431  33.0      113255.0     26468          825    9790.12
# 704          10705  33.0       81078.0     17293          607   18381.02
# ...

# %%
#14. Without creating another DataFrame,
# perform
# • remove duplicates
# • rename Target
# •  fill missing values
#• convert Balance to float
# •  display summary

df2.drop_duplicates()
# Out:
#       CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0           10001  58.0       49184.0      2139          581        NaN
# 1           10002  65.0      162964.0      6197          732    6356.54
# 2           10003  56.0       26956.0     37281          503  143203.92
# 3           10004  55.0       92926.0       925          463  139627.88
# 4           10005  66.0      108236.0      7198          394   75985.46
# ..            ...   ...           ...       ...          ...        ...
# 995         10996  34.0       81731.0     40980          761  181465.65
# 996         10997  47.0       42475.0      1176          780   26640.99
# 997         10998  31.0      120531.0     46929          733  147220.82
# 998         10999  21.0       33661.0     22314          540   94186.48
# 999         11000  63.0       31930.0       851          559  100908.40
#
#      Tenure Geography  Gender    Segment Target
# 0         2    France    Male        SME   Stay
# ...

# %%
df.rename(columns ={"Target":"Output"})
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Output
# ...

# %%
df['Age'].fillna('unknown')
df
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# ...

# %%
df["Balance"] = df["Balance"].astype(float)
df["Balance"]
# Out:
# 0             NaN
# 1         6356.54
# 2       143203.92
# 3       139627.88
# 4        75985.46
#           ...
# 1015     60353.03
# 1016    124512.07
# 1017     53850.09
# 1018    138100.05
# 1019          NaN
# Name: Balance, Length: 1020, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    CustomerID   1020 non-null   int64
#  1   Age           1020 non-null   object
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 87.8+ KB

# %%
#15. Data Engineer Task
# Load the dataset.
# Create another DataFrame containing only numeric columns.
# Drop
# CustomerID
# Target
# CustomerID
# Target
# Display summary.

import pandas as pd
df5 = pd.read_csv("C:\\Users\\Shree\\Downloads\\Task_dataset.csv")
df5
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# ...

# %%
df = df.select_dtypes(include=["number"])
df
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure  SeniorCitizen  HighCreditScore
# 0          2           58.0              581
# ...

# %%
df5.drop(columns ={"CustomerID"},axis=1)
df5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 df5.drop(columns ={"CustomerID"},axis=1)
#       2 df5
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df5.drop(columns = {"Target"},axis=1)
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment
# 0          2    France    Male        SME
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0    CustomerID      1020 non-null   int64
#  1   Age              970 non-null    float64
#  2   AnnualIncome     967 non-null    float64
#  3   Spending         1020 non-null   int64
#  4   CreditScore      1020 non-null   int64
#  5   Balance          969 non-null    float64
#  6   Tenure           1020 non-null   int64
#  7   SeniorCitizen    970 non-null    float64
#  8   HighCreditScore  1020 non-null   int64
# dtypes: float64(4), int64(5)
# memory usage: 71.8 KB

# %%
#16. – Mixed Cleaning
# Perform
# drop_duplicates()
# fillna()
# astype()
# rename()
# head()
# info()
# using only one DataFrame variable.

df.drop_duplicates()
df.
# Out:
#       CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0           10001  58.0       49184.0      2139          581        NaN
# 1           10002  65.0      162964.0      6197          732    6356.54
# 2           10003  56.0       26956.0     37281          503  143203.92
# 3           10004  55.0       92926.0       925          463  139627.88
# 4           10005  66.0      108236.0      7198          394   75985.46
# ..            ...   ...           ...       ...          ...        ...
# 995         10996  34.0       81731.0     40980          761  181465.65
# 996         10997  47.0       42475.0      1176          780   26640.99
# 997         10998  31.0      120531.0     46929          733  147220.82
# 998         10999  21.0       33661.0     22314          540   94186.48
# 999         11000  63.0       31930.0       851          559  100908.40
#
#      Tenure Geography  Gender    Segment Target
# 0         2    France    Male        SME   Stay
# ...

# %%
df['Age'].fillna('unknown')
df
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# ...

# %%
df["Balance"] = df["Balance"].astype(float)
df["Balance"]
# Out:
# 0             NaN
# 1         6356.54
# 2       143203.92
# 3       139627.88
# 4        75985.46
#           ...
# 1015     60353.03
# 1016    124512.07
# 1017     53850.09
# 1018    138100.05
# 1019          NaN
# Name: Balance, Length: 1020, dtype: float64

# %%
df.rename(columns = {"Target":"Output"})
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Output
# ...

# %%
df.head()
# Out:
#     CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    CustomerID   1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
#17. – Real Company Dataset
# Manager asks
# Remove duplicate records
# Fill missing values
# Rename all business columns
# Add company prefix
# Display summary
# Display target counts

print(df.duplicated().sum())
print(df.drop_duplicates())
df['Age'].fillna('unknown')
df
print(df.add_prefix("Company_"))
print(df.info())
print(df['Age'].value_counts(dropna = False))
# Out:
# 20
#       CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0           10001  58.0       49184.0      2139          581        NaN
# 1           10002  65.0      162964.0      6197          732    6356.54
# 2           10003  56.0       26956.0     37281          503  143203.92
# 3           10004  55.0       92926.0       925          463  139627.88
# 4           10005  66.0      108236.0      7198          394   75985.46
# ..            ...   ...           ...       ...          ...        ...
# 995         10996  34.0       81731.0     40980          761  181465.65
# 996         10997  47.0       42475.0      1176          780   26640.99
# 997         10998  31.0      120531.0     46929          733  147220.82
# 998         10999  21.0       33661.0     22314          540   94186.48
# 999         11000  63.0       31930.0       851          559  100908.40
#
#      Tenure Geography  Gender    Segment Target  SeniorCitizen  \
# ...

# %%
#18. – Customer Summary
# Generate
# Mean Balance
# Median Balance
# Mean Age
# Median AnnualIncome
# Then
# fill missing values using these statistics.

age_balance = df['Balance'].mean()
age_balance
# Out:
# np.float64(97523.53566563467)

# %%
balance_median = df['Balance'].median()
balance_median
# Out:
# 95100.06

# %%
age_median = df['Age'].median()
age_median
# Out:
# 44.0

# %%
age_AnnualIncome = df['AnnualIncome'].median()
age_AnnualIncome
# Out:
# 112358.0

# %%
#19. Transformation Challenge
# Create
# Income_in_Lakhs
# Balance_in_Lakhs

# SeniorCitizen
# HighCreditScore
# where
# SeniorCitizen = Age + 0
# HighCreditScore = CreditScore * 1
# (No conditional statements.)

df4["Income_in_Lakhs"] = df4["AnnualIncome"] > 100000
df4["Income_in_Lakhs"]

df4["Balance_in_Lakhs"]= df4["Balance"] > 100000
df4["Balance_in_Lakhs"]
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1015    False
# 1016     True
# 1017    False
# 1018     True
# 1019    False
# Name: Balance_in_Lakhs, Length: 1020, dtype: bool

# %%
df["SeniorCitizen"] = df["Age"] +0
df["SeniorCitizen"]
# Out:
# 0       58.0
# 1       65.0
# 2       56.0
# 3       55.0
# 4       66.0
#         ...
# 1015    43.0
# 1016    25.0
# 1017    49.0
# 1018    38.0
# 1019    62.0
# Name: SeniorCitizen, Length: 1020, dtype: float64

# %%
df["HighCreditScore"] = df["CreditScore"] * 1
df["HighCreditScore"]
# Out:
# 0       581
# 1       732
# 2       503
# 3       463
# 4       394
#        ...
# 1015    644
# 1016    303
# 1017    813
# 1018    722
# 1019    430
# Name: HighCreditScore, Length: 1020, dtype: int64

# %%
print(df.head())
# Out:
#     CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target  SeniorCitizen  HighCreditScore
# 0    France   Male        SME   Stay           58.0              581
# 1       USA   Male        SME  Churn           65.0              732
# 2    Canada   Male  Corporate   Stay           56.0              503
# 3       NaN   Male     Retail  Churn           55.0              463
# 4        UK  Other  Corporate  Churn           66.0              394

# %%
# Final Interview Project
# Your manager gives you a dirty customer dataset.
# Prepare the final dataset.
# Requirements
# Load dataset
# Check information
# Find missing values
# Remove duplicates
# Rename
# CustomerID
# AnnualIncome
# CreditScore
# Target
# Convert
# Age
# AnnualIncome
# Balance
# Fill missing values
# Remove
# Segment
# CustomerID
# Create new columns
# TotalMoney = Balance + AnnualIncome
# AgeAfter5Years = Age + 5
# MonthlyIncome = AnnualIncome / 12
# CreditScoreDouble = CreditScore * 2Display
# • Head
# • Tail
# • Sample
# • Describe
# • Target counts
# • Final information

import pandas as pd
df = pd.read_csv("C:\\Users\\Shree\\Downloads\\Task_dataset.csv")
df
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    CustomerID   1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
df.drop_duplicates()
# Out:
#       CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0           10001  58.0       49184.0      2139          581        NaN
# 1           10002  65.0      162964.0      6197          732    6356.54
# 2           10003  56.0       26956.0     37281          503  143203.92
# 3           10004  55.0       92926.0       925          463  139627.88
# 4           10005  66.0      108236.0      7198          394   75985.46
# ..            ...   ...           ...       ...          ...        ...
# 995         10996  34.0       81731.0     40980          761  181465.65
# 996         10997  47.0       42475.0      1176          780   26640.99
# 997         10998  31.0      120531.0     46929          733  147220.82
# 998         10999  21.0       33661.0     22314          540   94186.48
# 999         11000  63.0       31930.0       851          559  100908.40
#
#      Tenure Geography  Gender    Segment Target
# 0         2    France    Male        SME   Stay
# ...

# %%
df.isnull().sum()
# Out:
#  CustomerID      0
# Age             50
# AnnualIncome    53
# Spending         0
# CreditScore      0
# Balance         51
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# dtype: int64

# %%
df.rename(columns = {"CustomerID":"Customer_Id","AnnualIncome":"Annual_Income","CreditScore":"Credit_Score","Target":"Output"})
# Out:
#        CustomerID    Age  Annual_Income  Spending  Credit_Score    Balance  \
# 0            10001  58.0        49184.0      2139           581        NaN
# 1            10002  65.0       162964.0      6197           732    6356.54
# 2            10003  56.0        26956.0     37281           503  143203.92
# 3            10004  55.0        92926.0       925           463  139627.88
# 4            10005  66.0       108236.0      7198           394   75985.46
# ...            ...   ...            ...       ...           ...        ...
# 1015         10450  43.0       173620.0      7121           644   60353.03
# 1016         10753  25.0        54490.0     13794           303  124512.07
# 1017         10810  49.0        82062.0     47170           813   53850.09
# 1018         10267  38.0            NaN     10424           722  138100.05
# 1019         10059  62.0        97504.0     36833           430        NaN
#
#       Tenure Geography  Gender    Segment Output
# ...

# %%
df["Age"] = df["Age"].astype(float)
df["Age"]
# Out:
# 0       58.0
# 1       65.0
# 2       56.0
# 3       55.0
# 4       66.0
#         ...
# 1015    43.0
# 1016    25.0
# 1017    49.0
# 1018    38.0
# 1019    62.0
# Name: Age, Length: 1020, dtype: float64

# %%
df["Balance"] = df["Balance"].astype(float)
df["Balance"]
# Out:
# 0             NaN
# 1         6356.54
# 2       143203.92
# 3       139627.88
# 4        75985.46
#           ...
# 1015     60353.03
# 1016    124512.07
# 1017     53850.09
# 1018    138100.05
# 1019          NaN
# Name: Balance, Length: 1020, dtype: float64

# %%
df["AnnualIncome"] = df["AnnualIncome"].astype(float)
df["AnnualIncome"]
# Out:
# 0        49184.0
# 1       162964.0
# 2        26956.0
# 3        92926.0
# 4       108236.0
#           ...
# 1015    173620.0
# 1016     54490.0
# 1017     82062.0
# 1018         NaN
# 1019     97504.0
# Name: AnnualIncome, Length: 1020, dtype: float64

# %%
import pandas as pd
df4 = pd.read_csv("C:\\Users\\Shree\\Downloads\\Task_dataset.csv")
df4
df4["CreditScoreDouble"] = df4["CreditScore"] * 2
df4
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target  TotalMoney  AgeAfter5Years  \
# ...

# %%
df4["TotalMoney"] = df4["Balance"] + df4["AnnualIncome"]
df4
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target  TotalMoney  AgeAfter5Years  \
# ...

# %%
df4["AgeAfter5Years"] = df4["Age"] +5
df4
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target  TotalMoney  AgeAfter5Years  \
# ...

# %%
df4["MonthlyIncome"] = df4["AnnualIncome"] /12
df4
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0            10001  58.0       49184.0      2139          581        NaN
# 1            10002  65.0      162964.0      6197          732    6356.54
# 2            10003  56.0       26956.0     37281          503  143203.92
# 3            10004  55.0       92926.0       925          463  139627.88
# 4            10005  66.0      108236.0      7198          394   75985.46
# ...            ...   ...           ...       ...          ...        ...
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target  TotalMoney  AgeAfter5Years  \
# ...

# %%
df4.head()
# Out:
#     CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target  TotalMoney  AgeAfter5Years  \
# 0    France   Male        SME   Stay         NaN            63.0
# 1       USA   Male        SME  Churn   169320.54            70.0
# 2    Canada   Male  Corporate   Stay   170159.92            61.0
# 3       NaN   Male     Retail  Churn   232553.88            60.0
# 4        UK  Other  Corporate  Churn   184221.46            71.0
#
#    MonthlyIncome  CreditScoreDouble
# 0    4098.666667               1162
# ...

# %%
df4.tail()
# Out:
#        CustomerID    Age  AnnualIncome  Spending  CreditScore    Balance  \
# 1015         10450  43.0      173620.0      7121          644   60353.03
# 1016         10753  25.0       54490.0     13794          303  124512.07
# 1017         10810  49.0       82062.0     47170          813   53850.09
# 1018         10267  38.0           NaN     10424          722  138100.05
# 1019         10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target  TotalMoney  AgeAfter5Years  \
# 1015       2       USA   Other  Corporate   Stay   233973.03            48.0
# 1016       4     India     NaN  Corporate  Churn   179002.07            30.0
# 1017       8   Germany  Female     Retail   Stay   135912.09            54.0
# 1018       6   Germany   Other  Corporate   Stay         NaN            43.0
# 1019      10    Canada   Other        NaN  Churn         NaN            67.0
#
#       MonthlyIncome  CreditScoreDouble
# ...

# %%
df.sample()
# Out:
#       CustomerID    Age  AnnualIncome  Spending  CreditScore   Balance  \
# 575         10576  19.0      144253.0     10744          846  43973.15
#
#      Tenure Geography  Gender Segment Target
# 575       6   Germany  Female     SME   Stay

# %%
df.describe()
# Out:
#         CustomerID          Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     969.000000  1020.000000
# mean    97523.535666     5.261765
# std     55796.562543     3.185330
# min       547.600000     0.000000
# 25%     50077.860000     2.000000
# 50%     95100.060000     5.000000
# 75%    143947.810000     8.000000
# ...

# %%
df4["Target"].value_counts()
# Out:
# Target
# Churn    515
# Stay     505
# Name: count, dtype: int64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0    CustomerID        1020 non-null   int64
#  1   Age                970 non-null    float64
#  2   AnnualIncome       967 non-null    float64
#  3   Spending           1020 non-null   int64
#  4   CreditScore        1020 non-null   int64
#  5   Balance            969 non-null    float64
#  6   Tenure             1020 non-null   int64
#  7   Geography          969 non-null    object
#  8   Gender             968 non-null    object
#  9   Segment            969 non-null    object
#  10  Target             1020 non-null   object
#  11  TotalMoney         920 non-null    float64
#  12  AgeAfter5Years     970 non-null    float64
#  13  MonthlyIncome      967 non-null    float64
#  14  CreditScoreDouble  1020 non-null   int64
# dtypes: float64(6), int64(5), object(4)
# ...
