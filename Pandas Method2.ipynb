# %% [markdown]
# # Easy Level (1–10)

# %%
#1. Load the dataset and display the first 10 records.
import pandas as pd
df = pd.read_csv("C:\\Users\\Shree\\Downloads\\Bank_customer_churn.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
#2. Display the last 15 customers.

df.tail(15)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9985       9986    15586914       Nepean          659    France    Male   36
# 9986       9987    15581736     Bartlett          673   Germany    Male   47
# 9987       9988    15588839      Mancini          606     Spain    Male   30
# 9988       9989    15589329      Pirozzi          775    France    Male   30
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# ...

# %%
#3. Show 7 random customer records.
df.sample(7)
# Out:
#       RowNumber  CustomerId       Surname  CreditScore Geography  Gender  Age  \
# 5576       5577    15635964           Eve          566   Germany    Male   65
# 6771       6772    15621818     Anayolisa          747   Germany    Male   29
# 8336       8337    15788480      Pagnotto          786   Germany  Female   33
# 1623       1624    15804516       Builder          589    France    Male   38
# 497         498    15733616  Sopuluchukwu          806    France    Male   40
# 7823       7824    15616029         Adams          705    France    Male   32
# 363         364    15745088          Chen          443   Germany  Female   29
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5576       4  120100.41              1          1               0
# 6771       7  117726.33              1          1               1
# 8336       0  122325.58              1          0               0
# 1623       2       0.00              1          1               0
# ...

# %%
#4. Print complete dataset information and identify:
# • Total columns
# • Data type of each column
# • Missing values

cols = df.shape
print("no.of columns:",cols)
df1 = df.info()
df1
df2 = df.isnull()
df2
# Out:
# no.of columns: (10000, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# ...

# %%
#5. Find missing values in every column.

df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#6. Display only numerical columns.

int_column=df.select_dtypes(include = ["int64"]).columns
int_column
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Exited'],
#       dtype='object')

# %%
#7. Generate the statistical summary of numerical columns.

df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
#8. Find duplicate rows and print how many exist.

duplicates = df.duplicated().sum()
duplicates
rows = df.shape
print("no.of rows:",rows)
# Out:
# no.of rows: (10000, 14)

# %%
#9. Remove duplicate rows and store the cleaned dataset.

df.drop_duplicates(inplace = True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#10. Count how many customers have exited and how many have not exited.

counts = df["Exited"].value_counts()
print(counts)
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %% [markdown]
# # Medium Level (11–20)

# %%
#11. Rename the following columns:
# CustomerId → Customer_ID
# CreditScore → Credit_Score
# EstimatedSalary → Salary
# Exited → Churn

df.rename(columns = {"CustomerId":"Customer_ID","CreditScore":"Credit_Score","EstimatedSalary":"Salary","Exited":"Churn"},inplace = True)
df.columns
# Out:
# Index(['RowNumber', 'Customer_ID', 'Surname', 'Credit_Score', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'Salary', 'Churn'],
#       dtype='object')

# %%
#12. Add the prefix Bank_ to every column name.

df.add_prefix("Bank_")
# Out:
#     Bank_Age
# 0       10.0
# 1       23.0
# 2       45.0
# 3       56.0
# 4       66.0
# 5        NaN
# 6       34.0
# 7        NaN
# 8       12.0
# 9       13.0
# 10      54.0
# 11       NaN

# %%
#13. Convert the Age column into float datatype.

import numpy as np
dicts = {"Age":[10,23,45,56,66,np.nan,34,np.nan,12,13,54,np.nan]}
df = pd.DataFrame(dicts)
df.head()
df['Age'] = df['Age'].astype("float")
df['Age']
# Out:
# 0     10.0
# 1     23.0
# 2     45.0
# 3     56.0
# 4     66.0
# 5      NaN
# 6     34.0
# 7      NaN
# 8     12.0
# 9     13.0
# 10    54.0
# 11     NaN
# Name: Age, dtype: float64

# %%
#14. Convert the Exited column into string datatype.

df["Exited"] = df["Exited"].astype("str")
df['Exited']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: object

# %%
#15. Suppose the Balance column has missing values.
# Replace them using the mean of the Balance column.

df['Balance'] = df["Balance"].fillna(balance_mean)
df['Balance']

rep_bal = df["Balance"].fillna(balance_mean)
rep_bal
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
#16. Suppose the Age column has missing values. Replace them using the median age.
age_median = df['Age'].median()
age_median
# Out:
# 34.0

# %%
#17. Display only the first five rows after renaming the columns.

df.rename(index = {0:"first",1:"second",2:"third",3:"fourth",4:"fifth"})
# Out:
#         RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# first           1    15634602   Hargrave          619    France  Female   42
# second          2    15647311       Hill          608     Spain  Female   41
# third           3    15619304       Onio          502    France  Female   42
# fourth          4    15701354       Boni          699    France  Female   39
# fifth           5    15737888   Mitchell          850     Spain  Female   43
# ...           ...         ...        ...          ...       ...     ...  ...
# 9995         9996    15606229   Obijiaku          771    France    Male   39
# 9996         9997    15569892  Johnstone          516    France    Male   35
# 9997         9998    15584532        Liu          709    France  Female   36
# 9998         9999    15682355  Sabbatini          772   Germany    Male   42
# 9999        10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
#18. Create a new DataFrame by dropping these columns:
# RowNumber
# CustomerId
# Surname
# Display the first 10 rows.

df_new = df.drop({"RowNumber","CustomerId","Surname"},axis = 1)
df_new
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
#19. Drop the Geography column and display dataset information again.

# %%
#20. Rename NumOfProducts to Products and HasCrCard to CreditCard.
df.rename(columns = {"NumOfProducts":"Product","HasCrCard":"CreditCard"},inplace = True)
df.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'Product', 'CreditCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# # Hard Level (21–30)

# %%
#21. (Real Company Task)
# Your manager wants cleaner column names.
# Rename every column as follows:
# RowNumber → Row_No
# CustomerId → Customer_ID
# Surname → Last_Name
# CreditScore → Credit_Score
# Geography → Country
# Gender → Sex
# EstimatedSalary → Salary
# Exited → Target
# Display the first five rows.


df.rename(columns = {"RowNumber":"Row_No","CustomerId":"Customer_ID","Surname":"Last_Name","CreditScore":"Credit_Score","Geography":"Country","Gender":"Sex","EstimatedSalary":"Salary","Exited":"Target"},inplace = True)
df.columns

df.head(5)
# Out:
#    Row_No  Customer_ID Last_Name  Credit_Score Country     Sex  Age  Tenure  \
# 0       1     15634602  Hargrave           619  France  Female   42       2
# 1       2     15647311      Hill           608   Spain  Female   41       1
# 2       3     15619304      Onio           502  France  Female   42       8
# 3       4     15701354      Boni           699  France  Female   39       1
# 4       5     15737888  Mitchell           850   Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  Target
# 0       0.00              1          1               1  101348.88       1
# 1   83807.86              1          0               1  112542.58       0
# 2  159660.80              3          1               0  113931.57       1
# 3       0.00              2          0               0   93826.63       0
# 4  125510.82              1          1               1   79084.10       0

# %%
#22. Create a new DataFrame that contains only numeric columns.
# Then generate its statistical summary.

int_column=df.select_dtypes(include = ["int64"]).columns

df.describe()
# Out:
#             Row_No   Customer_ID  Credit_Score           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
#23. Your company received duplicate customer records.
# Tasks:
# • Count duplicates.
# • Remove duplicates.
# • Display dataset information after cleaning.

df.drop_duplicates
df.duplicated().sum()
df.head()
# Out:
#    Row_No  Customer_ID Last_Name  Credit_Score Country     Sex  Age  Tenure  \
# 0       1     15634602  Hargrave           619  France  Female   42       2
# 1       2     15647311      Hill           608   Spain  Female   41       1
# 2       3     15619304      Onio           502  France  Female   42       8
# 3       4     15701354      Boni           699  France  Female   39       1
# 4       5     15737888  Mitchell           850   Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  Target
# 0       0.00              1          1               1  101348.88       1
# 1   83807.86              1          0               1  112542.58       0
# 2  159660.80              3          1               0  113931.57       1
# 3       0.00              2          0               0   93826.63       0
# 4  125510.82              1          1               1   79084.10       0

# %%
#24. Management wants every column name to begin with
# Customer_
# Apply this transformation using the appropriate method.

df.add_prefix("Customer_")
# Out:
#       Customer_Row_No  Customer_Customer_ID Customer_Last_Name  \
# 0                   1              15634602           Hargrave
# 1                   2              15647311               Hill
# 2                   3              15619304               Onio
# 3                   4              15701354               Boni
# 4                   5              15737888           Mitchell
# ...               ...                   ...                ...
# 9995             9996              15606229           Obijiaku
# 9996             9997              15569892          Johnstone
# 9997             9998              15584532                Liu
# 9998             9999              15682355          Sabbatini
# 9999            10000              15628319             Walker
#
#       Customer_Credit_Score Customer_Country Customer_Sex  Customer_Age  \
# 0                       619           France       Female            42
# ...

# %%
#25. After renaming the columns, convert
# Age
# Balance
# Salary
# to float datatype.
# Print dataset information.

int_column=df.select_dtypes(include = ["int64"]).columns
len(int_column)
# Out:
# 9

# %%
#26. Assume CreditScore contains missing values.
# Replace them with the median CreditScore.

CreditScore_median = df['CreditScore'].median()
CreditScore_median
# Out:
# 652.0

# %%
#27.Assume EstimatedSalary contains missing values.
# Replace them with the mean salary.
# Then print the first eight rows.
df1 = pd.read_csv("C:\\Users\\Shree\\Downloads\\Bank_customer_churn.csv")

mean_salary = df1["EstimatedSalary"].mean()
df1["EstimatedSalary"].fillna(mean_salary)
print(df1.head(8))
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# ...

# %%
#28.(Data Cleaning Challenge)
# Perform all the following:
# • Remove duplicate rows.
# • Rename Exited to Target.
# • Convert Target to string.
# • Display dataset information.

df= df.drop_duplicates()
df.rename(columns={"Exited":"Target"})
df["Target"] = df["Target"].astype(str)
df.info
# Out:
# <bound method DataFrame.info of       Row_No  Customer_ID  Last_Name  Credit_Score  Country     Sex  Age  \
# 0          1     15634602   Hargrave           619   France  Female   42
# 1          2     15647311       Hill           608    Spain  Female   41
# 2          3     15619304       Onio           502   France  Female   42
# 3          4     15701354       Boni           699   France  Female   39
# 4          5     15737888   Mitchell           850    Spain  Female   43
# ...      ...          ...        ...           ...      ...     ...  ...
# 9995    9996     15606229   Obijiaku           771   France    Male   39
# 9996    9997     15569892  Johnstone           516   France    Male   35
# 9997    9998     15584532        Liu           709   France  Female   36
# 9998    9999     15682355  Sabbatini           772  Germany    Male   42
# 9999   10000     15628319     Walker           792   France  Female   28
#
# ...

# %%
#29.(Transformation Challenge)
# Create a copy of the dataset.
# Perform these transformations:
# • Rename Gender to CustomerGender
# • Rename Geography to Country
# • Add prefix Bank_
# • Remove RowNumber
# • Display first 10 rows

df_copy = df.copy()
df_copy.rename(columns={"Gender":"CustomerGender","Geography":"Country"},inplace = True)
df_copy = df_copy.add_prefix("Bank_")
df_copy.drop(columns=["Bank_RowNumber"],inplace = True)
print(df_copy.head(10))
# Out:
#    Bank_CustomerId Bank_Surname  Bank_CreditScore Bank_Country  \
# 0         15634602     Hargrave               619       France
# 1         15647311         Hill               608        Spain
# 2         15619304         Onio               502       France
# 3         15701354         Boni               699       France
# 4         15737888     Mitchell               850        Spain
# 5         15574012          Chu               645        Spain
# 6         15592531     Bartlett               822       France
# 7         15656148       Obinna               376      Germany
# 8         15792365           He               501       France
# 9         15592389           H?               684       France
#
#   Bank_CustomerGender  Bank_Age  Bank_Tenure  Bank_Balance  \
# 0              Female        42            2          0.00
# 1              Female        41            1      83807.86
# 2              Female        42            8     159660.80
# ...

# %%
#30. Real Industry Mini Project

# Your manager asks you to prepare a cleaned dataset for the Machine Learning team.
# Perform all of these steps:
# 1. Load the dataset.
# 2. Display dataset information.
# 3. Check missing values.
# 4. Remove duplicate rows.
# 5. Rename the following columns:
# o CustomerId → Customer_ID
# o CreditScore → Credit_Score
# o EstimatedSalary → Salary
# o Exited → Target
# 6. Convert:
# o Age → float
# o Balance → float
# o Target → string
# 7. Replace missing values:
# o Age → median
# o Balance → mean
# 8 . Remove:
# o RowNumber
# o Surname
# 9. Display:
# o First 10 rows
# o Statistical summary
# o Value counts of Target
# o Final dataset information

df = pd.read_csv("C:\\Users\\Shree\\Downloads\\Bank_customer_churn.csv")
df
print(df.info())
print(df.isnull().sum())
df = df.drop_duplicates()

df.rename(columns={
    "CustomerId": "Customer_ID",
    "CreditScore": "Credit_Score",
    "EstimatedSalary": "Salary",
    "Exited": "Target"
}, inplace=True)

df["Age"] = df["Age"].astype(float)
df["Balance"] =df["Balance"].astype(float)
df["Target"] = df["Target"].astype(str)

df["Age"].fillna(df["Age"].median())
df["Balance"].fillna(df["Balance"].mean())
df.drop(columns = ["RowNumber","Surname"])

print(df.head(10))
print(df.describe())
print(df["Target"].value_counts())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# None
# RowNumber          0
# CustomerId         0
# Surname            0
# ...

# %% [markdown]
# # Bonus Challenge (Create New Columns)

# %%
#B1 Create a new column: TotalMoney = Balance + EstimatedSalary
df2 = pd.read_csv("C:\\Users\\Shree\\Downloads\\Bank_customer_churn.csv")

df2["TotalMoney"] = df2["Balance"] + df2["EstimatedSalary"]
print(df2.head(10))
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
# B2 Create a new column: DoubleScore = CreditScore × 2

df["DoubleScore"] = df["Credit_Score"] * 2
print(df.head(10))
# Out:
#    RowNumber  Customer_ID   Surname  Credit_Score Geography  Gender   Age  \
# 0          1     15634602  Hargrave           619    France  Female  42.0
# 1          2     15647311      Hill           608     Spain  Female  41.0
# 2          3     15619304      Onio           502    France  Female  42.0
# 3          4     15701354      Boni           699    France  Female  39.0
# 4          5     15737888  Mitchell           850     Spain  Female  43.0
# 5          6     15574012       Chu           645     Spain    Male  44.0
# 6          7     15592531  Bartlett           822    France    Male  50.0
# 7          8     15656148    Obinna           376   Germany  Female  29.0
# 8          9     15792365        He           501    France    Male  44.0
# 9         10     15592389        H?           684    France    Male  27.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# 0       2       0.00              1          1               1  101348.88
# ...

# %%
# B3
# Create a new column:
# AgeAfter10Years = Age + 10

df["AgeAfter10Years"] = df["Age"] + 10
print(df.head(10))
# Out:
#    RowNumber  Customer_ID   Surname  Credit_Score Geography  Gender   Age  \
# 0          1     15634602  Hargrave           619    France  Female  42.0
# 1          2     15647311      Hill           608     Spain  Female  41.0
# 2          3     15619304      Onio           502    France  Female  42.0
# 3          4     15701354      Boni           699    France  Female  39.0
# 4          5     15737888  Mitchell           850     Spain  Female  43.0
# 5          6     15574012       Chu           645     Spain    Male  44.0
# 6          7     15592531  Bartlett           822    France    Male  50.0
# 7          8     15656148    Obinna           376   Germany  Female  29.0
# 8          9     15792365        He           501    France    Male  44.0
# 9         10     15592389        H?           684    France    Male  27.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# 0       2       0.00              1          1               1  101348.88
# ...

# %%
# B4
# Create a new column:
# HasBalance = Balance
# Replace missing values in this new column using the mean.

df["HasBalance"] = df["Balance"]
mean_balance = df["HasBalance"].mean()
df["HasBalance"].fillna(mean_balance)
print(df.head(10))
# Out:
#    RowNumber  Customer_ID   Surname  Credit_Score Geography  Gender   Age  \
# 0          1     15634602  Hargrave           619    France  Female  42.0
# 1          2     15647311      Hill           608     Spain  Female  41.0
# 2          3     15619304      Onio           502    France  Female  42.0
# 3          4     15701354      Boni           699    France  Female  39.0
# 4          5     15737888  Mitchell           850     Spain  Female  43.0
# 5          6     15574012       Chu           645     Spain    Male  44.0
# 6          7     15592531  Bartlett           822    France    Male  50.0
# 7          8     15656148    Obinna           376   Germany  Female  29.0
# 8          9     15792365        He           501    France    Male  44.0
# 9         10     15592389        H?           684    France    Male  27.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# 0       2       0.00              1          1               1  101348.88
# ...

# %%
#B5
# Create a new column:
# SalaryInLakhs = EstimatedSalary / 100000

df["SalaryInLakhs"] = df["EstimatedSalary"] / 100000
print(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EstimatedSalary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 5
#       1 #B5
#       2 # Create a new column:
# ...
