# %%
#1.Create a list named students with 5 student names and print it.
names=["Vaishnavi","Vidhya","Shweta","Akanksha","Mahi"]
names
# Out:
# ['Vaishnavi', 'Vidhya', 'Shweta', 'Akanksha', 'Mahi']

# %%
#2.Create a list numbers = [10, 20, 30, 40, 50] and print its type and length using len().

numbers = [10,20,30,40,50]
print(type(numbers))
print(len(numbers))
# Out:
# <class 'list'>
# 5

# %%
#3.Create an empty list and append 3 numbers into it using append().

list=["Mango","Banana","Strawberry"]
add=["Apple","Pineapple"]
list.append(add)
print(list)
# Out:
# ['Mango', 'Banana', 'Strawberry', ['Apple', 'Pineapple']]

# %%
#4.Given lst = [1, 2, 3], use extend() to add [4, 5, 6] to it.

lst=[1,2,3]
add1=[4,5,6]
lst.extend(add1)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#5.Use insert() to add number 100 at index 2 in the list [10, 20, 30, 40].

list=[10,20,30,40]
list.insert(2,100)
print(list)
# Out:
# [10, 20, 100, 30, 40]

# %%
#6.Remove the element 50 from the list [10, 20, 50, 30, 50] using remove().

list=[10,20,50,30,50]
list.remove(50)
print(list)
# Out:
# [10, 20, 30, 50]

# %%
#7.Clear all elements from the list data = [1, 2, 3, 4, 5] using clear().

list = [1,2,3,4,5]
list.clear()
print(list)
# Out:
# []

# %%
#8.Use pop() to remove the last element from lst = [5, 10, 15, 20] and print the list.

lst=[5,10,15,20]
lst.pop(3)
print(lst)
# Out:
# [5, 10, 15]

# %%
#9.Find the index of 25 in the list [10, 15, 25, 30, 40] using index().

list=[10,15,25,30,40]
list.index(25)
# Out:
# 2

# %%
#10.Count how many times 7 appears in the list [7, 2, 7, 5, 7, 8] using count().

list=[7,2,7,5,7,8]
list.count(7)
# Out:
# 3

# %%
#11.Sort the list [45, 12, 78, 23, 56] in ascending order using sort().

list=[45,12,78,23,56]
list.sort()
print(list)
# Out:
# [12, 23, 45, 56, 78]

# %%
#13.Reverse the list fruits=["apple","banana","mango","orange"]using reverse().

fruits=["apple","banana","mango","orange"]
fruits.reverse()
print(fruits)
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
#14.Create a copy of list original=[1,2,3,4] using copy() and print both.

list=[1,2,3,4]
list1=list.copy()
print(list)
print(list1)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
#15.Take a sentence from user (e.g."I love Python Programming") and convert it into a list of words using split().

sent = input("Enter a sentence:")
print(sent)
sent1=sent.split()
print(sent1)
# Out:
# Enter a sentence: I love Python Programming

# %%
#16.Create a list of 5 numbers. Append 3 more numbers, then sort it in descending order.

list=[1,2,3,4,5]

list.sort(reverse=True)
print(list)
add=[7,8,9]

list.append(add)
print(list)
# Out:
# [5, 4, 3, 2, 1]
# [5, 4, 3, 2, 1, [7, 8, 9]]

# %%
#17.Create a list.Insert"Python" at index 0,then remove the last element using pop(), and print the length.

list=["Python"]
list1=list.pop(0)
print(list)
print(len(list))
# Out:
# []
# 0

# %%
#18.Take 5 city names as input from user and store them in a list. Then print them in reverse order.

city1=input("Enter a city1 name:")
city2=input("Enter a city2 name:")
city3=input("Enter a city3 name:")
city4=input("Enter a city4 name:")
city5=input("Enter a city5 name:")

List=[city1,city2,city3,city4,city5]
print(List)

List.reverse()
print(List)
# Out:
# Enter a city1 name: Nanded
# Enter a city2 name: Hyd
# Enter a city3 name: Nashik
# Enter a city4 name: Nagpur
# Enter a city5 name: Delhi
# ['Nanded', 'Hyd', 'Nashik', 'Nagpur', 'Delhi']
# ['Delhi', 'Nagpur', 'Nashik', 'Hyd', 'Nanded']

# %%
#19. Given data =[10,20,30,20,40,20], remove all occurrences of 20 (use loop or multiple remove).

data=[10,20,30,20,40,20]
for i in data:
    i=20
    data.remove(20)


print(data)
# Out:
# [10, 30, 40]

# %%
#20.Create a list of student marks. Sort it, find the highest and lowest mark using list methods, and print them.

student_marks=[10,33,55,78,99,100]
print(student_marks)

print("lowest marks of student_marks",student_marks[0])
print("Highest marks of student_marks",student_marks[5])
# Out:
# [10, 33, 55, 78, 99, 100]
# lowest marks of student_marks 10
# Highest marks of student_marks 100
