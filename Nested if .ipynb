# %%
#1. Take a number as input. If the number is positive, check whether it is even or odd and print the result.

num = int(input("Enter a num:"))

if num>0:
    print("It is positive:")
    
    if num%2==0:
        print("Even no.:")
    else:
        print("Odd no.:")
else:
    print("It is not positive no.:")
# Out:
# Enter a num: 4
# It is positive:
# Even no.:

# %%
#2.Take age as input. If age is greater than or equal to 18, check if the person is a
#senior citizen (age >= 60) or adult.

age=int(input("Enter a age:"))

if age>=18:
    if age>=60:
        print("senior citizen:")
    else:
        print("adult:")
else:
    print("ur age is not 18:")
# Out:
# Enter a age: 68
# senior citizen:

# %%
#3. Take a single character. If it is an alphabet, check whether it is uppercase or lowercase.

ch = input("Enter a character:")

if ch.isalpha():
    print("It is alphabet:")
    if ch.islower():
        print("in Lowercase:")
    else:
        print("in Uppercase:")
else:
    print("Not a alphabet:")
# Out:
# Enter a character: d
# It is alphabet:
# in Lowercase:

# %%
#4. Take three numbers as input and print the largest number using nested if
#statements (without using max()).

num1 = int(input("Enter a no1:"))
num2 = int(input("Enter a no2:"))
num3 = int(input("Enter a no3:"))

if num1>num2:
    if num1>num3:
        print("num1 is greater:",num1)
    else:
        print("num3 is greater:",num3)
else:
    if num2>num3:
        print("num2 is greater:",num2)
    else:
        print("num3 is greater:",num3)
# Out:
# Enter a no1: 34
# Enter a no2: 67
# Enter a no3: 89
# num3 is greater: 89

# %%
#5. Take student marks. If marks >= 40 (Pass), then further check if marks >= 75 to
#print "Pass with Distinction". 

marks= int(input("Enter a marks:"))

if marks>=40:
    if marks>=75:
        print("pass with Distinction:")
    else:
        print("pass:")
else:
    print("Fail:")
# Out:
# Enter a marks: 35
# Fail:

# %%
#6. Take a number. If it is divisible by 2,check if it is also divisible by 4.

num = int(input("Enter a num:"))
if num%2==0:
    if num%4==0:
        print("num is divisible by 4:")
    else:
        print("num is divisible by 2:")
else:
    print("num is not divisible by 2 and 4:")
# Out:
# Enter a num: 8
# num is divisible by 4:

# %%
#7. Take username and password. If username is "admin", then check if the password is correct.

username = "admin"
password = 12345

username1=input("Enter a username:")
password1=int(input("Enter a pass:"))

if username1==username:
    print("username is correct:")
    if password1==password:
        print("password is correct:")
    else:
        print("password is not correct:")
else:
    print("username is not correct:")
# Out:
# Enter a username: admin
# Enter a pass: 12345
# username is correct:
# password is correct:

# %%
#8. Take three sides of a triangle. First check if they form a valid triangle, then check if it is Equilateral, Isosceles, or Scalene.

side1 = int(input("Enter a side1:"))
side2 = int(input("Enter a side2:"))
side3 = int(input("Enter a side3:"))


if side1+side2+side3==90:
    print("valid triangle:")
    if side1==side2==side3:
        print("Equilateral triangle:")
    elif side1==side2 and side2==side3 and side3==side1:
            print("Isosceles triangle:")
    else:
         print("Scalene:")
else:
    print("Not a valid triangle:")
# Out:
# Enter a side1: 30
# Enter a side2: 30
# Enter a side3: 30
# valid triangle:
# Equilateral triangle:

# %%
#9. Take salary and years of experience. If salary > 50000, check experience to decide "Manager" or "Senior Manager".

salary= int(input("Enter a salary:"))
year= int(input("Enter a year:"))
if salary>50000:
    if year<15:
        print("Manager:")
    else:
        print("Senior Manager:")
# Out:
# Enter a salary: 70000
# Enter a year: 12
# Manager:

# %%
#10.Take a character. If it is a letter, check if it is vowel or consonant. If it is a digit,
#print "Digit". Else print "Special Character".

ch = input("Enter a character:")
if ch.isalpha():
    if ch=="AaEeIiOoUu":
        print("Vowels:")
    else:
        print("Consonant:")
else:
    if ch.isdigit():
        print("it is digit:")
    else:
        print("Special Character:")
# Out:
# Enter a character: apple
# Consonant:

# %%
#11.Take a year as input. Check if it is a leap year using nested conditions.

year = int(input("Enter a year:"))
if year%4==0:
        print("leap year:")
else:
        print("Not a leap year:")
# Out:
# Enter a year: 2004
# leap year:

# %%
#12. Take temperature. If temperature > 30 print "Hot", if between 20-30 print "Warm",
#else "Cold" using nested if.

temp=50
if temp>30:
    print("Hot")
    if temp>20 and temp<30:
        print("Warm:")
else:
    print("It is cold:")
# Out:
# Hot

# %%
#13. Take three numbers. Check if all three are equal, or any two are equal using nested if.

n1=33
n2=33
n3=33

if n1==n2==n3:
    print("They are equal:")
    if n1!=n3 and n1!=n2:
        print("n1 is not equal:")
    elif n2!=n3 and n3!=n2:
        print("n2 is not equal:")
else:
    print("They are not equal:")
# Out:
# They are equal:

# %%
#14. Take a number. If it is positive and even, print "Positive Even Number".

num1 = -23
if num1>=0:
    
    if num1%2==0:
        print("Positive Even Number:")
    else:
        print("positive")
else:
    print("Not is positive no.:")
# Out:
# Not is positive no.:

# %%
#15. Take marks of 5 subjects. If average >= 60, then check if all subjects are above 40 marks.

sub1=int(input("Enter a marks of sub1:"))
sub2=int(input("Enter a marks of sub2:"))
sub3=int(input("Enter a marks of sub3:"))
sub4=int(input("Enter a marks of sub4:"))
sub5=int(input("Enter a marks of sub5:"))

average=sub1+sub2+sub3+sub4+sub5/5

if average>=60:
    if sub1>40 and sub2>40 and sub3>40 and sub4>40 and sub5>40:
        print("Average marks:")
    else:
        print("Below marks:")
else:
    print("Fail:")
# Out:
# Enter a marks of sub1: 34
# Enter a marks of sub2: 45
# Enter a marks of sub3: 56
# Enter a marks of sub4: 67
# Enter a marks of sub5: 78
# Below marks:

# %%
#16. Take username, password, and age. If username and password are correct and
#age >= 18, print "Login Successful". Else if age < 18, print age restriction
#message.

username="admin"
password=123456
age=11
if username=="admin":
    if password==12345:
        print("username and password are correct:")
if age>=18:
    print("Login Sucessful:")
else:
        print("age is not equal to 18:")
# Out:
# age is not equal to 18:

# %%
#17. Take a number. Check if it is divisible by both 3 and 5 using nested if.

num1=15

if num1%3==0 and num1%5==0:
    print("num is divisible by 3 and 5:")
else:
    print("num is not divisible by 3 and 5:")
# Out:
# num is divisible by 3 and 5:

# %%
#18. Take three sides of a triangle. Check if valid, then check if it is a right-angled
#triangle using Pythagoras theorem.

# %%
#19.Take a grade (A, B, C, D, F) and print full description using if-elif-else (Excellent,
# Good, Average, etc.).

grade = input("Enter grade (A, B, C, D, F): ")

if grade == "A":
    print("Excellent")
elif grade == "B":
    print("Good")
elif grade == "C":
    print("Average")
elif grade == "D":
    print("Below Average")
elif grade == "F":
    print("Fail")
else:
    print("Invalid Grade")
# Out:
# Enter grade (A, B, C, D, F):  A
# Excellent

# %%
#20. Take income. If income > 1000000, check tax slab. If income between 500000-
# 1000000, different slab. Else print "Low Income".

income= int(input("Enter ur income:"))

if income>1000000:
    print("High Income:")
elif 500000<=income<=1000000:
        print("Medium Income:")
else:
        print("Low Income:")
# Out:
# Enter ur income: 750000
# Medium Income:

# %%
#21. (Hard) Take three sides of a triangle as input. First check if they can form a valid
# triangle (sum of any two sides > third side). If valid, then further check and print
# whether the triangle is Equilateral, Isosceles, or Scalene.

A = int(input("Enter a side1:"))
B = int(input("Enter a side2:"))
C = int(input("Enter a side3:"))

if A+B>C:
    print("Valid Triangle:")
    if A==B==C:
        print("Equilateral:")
    elif A==B and B==C or C==A:
        print("Isosceles:")
    else:
        print("Scalene:")
else:
    print("Not a valid traingle:")
# Out:
# Enter a side1: 23
# Enter a side2: 34
# Enter a side3: 56
# Valid Triangle:
# Scalene:

# %%
#22. (Hard) Take a student's marks in 5 subjects. Calculate the average. If average >=
# 60, then check if all individual subjects are above 40. If yes, print "Pass with Good
# Performance", else print "Pass but Weak in some subjects". If average < 60, print
# "Fail".

std1 = int(input("enter ur marks:"))
std2 = int(input("enter ur marks:"))
std3 = int(input("enter ur marks:"))
std4 = int(input("enter ur marks:"))
std5 = int(input("enter ur marks:"))

avg =(std1+std2+std3+std4+std5)/5

if avg>=60:
    if std1>40 and std2>40 and std3>40 and std4>40:
        print("Pass with Good Performance:")
    else:
        print("Pass but weak in some subjects:")
else:
    print("Fail:")
# Out:
# enter ur marks: 34
# enter ur marks: 56
# enter ur marks: 78
# enter ur marks: 66
# enter ur marks: 78
# Pass but weak in some subjects:

# %%
#23. (Hard) Take username, password, and age as input.
# • If username == "admin" and password == "python123" and age >= 18, print
# "Login Successful".
# • Else if age < 18, print "You are too young to login".
# • Else if username is wrong, print "Invalid Username".
# • Else print "Invalid Password".

username= input("Enter ur username:")
password=input("Enter ur password:")
age = int(input("Enter ur age:"))

if username=="admin" and password=="python123" and age>=18:
    print("Login Successful:")
elif age<18:
    print("You are too yound to login:")
elif username!="admin":
    print("Invalid Username:")
else:
    print("Invalid Password:")
# Out:
# Enter ur username: admin
# Enter ur password: python123
# Enter ur age: 20
# Login Successful:

# %%
#24. (Hard) Take a number as input. Check if the number is positive. If positive, check
# if it is divisible by both 3 and 5. If yes, print "FizzBuzz". If only divisible by 3 print
# "Fizz", only by 5 print "Buzz". If negative, print "Negative Number".

num = int(input("Enter a num:"))
if num>0:
    print("no. is positive:")
    if num%3==0 and num%5==0:
        print("FizzBuzz:")
    elif num%3==0:
        print("Fizz")
    else: num%5==0
    print("Buzz")
else:
    print("Negative Number:")
# Out:
# Enter a num: 4
# no. is positive:
# Buzz

# %%
#25. (Hard) Take three numbers. First check if all three are equal. If not, check which
# one is the largest. Also check if the largest number is even or odd and print all
# information accordingly.

n1 = int(input("Enter ur no."))
n2 = int(input("Enter ur no."))
n3 = int(input("Enter ur no."))

if n1==n2==n3:
    print("All numbers are equal:") 
else:
    if n1>=n2 and n1>=n3:
        print("n1 is greater:",n1)
    elif n2>=n1 and n2>=n3:
        print("n2 is greater:",n2)
    else:
        print("n3 is greater:",n3)

if num%2==0:
    print("no. is even:")
else:
    print("No. is odd:")
# Out:
# Enter ur no. 54
# Enter ur no. 67
# Enter ur no. 78
# n3 is greater: 78
# no. is even:
