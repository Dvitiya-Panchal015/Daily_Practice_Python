# %%
#1. Write a program to check whether a number is positive, negative, or zero.

num=34

if num>=0:
    print("no is positive:")
elif num<=0:
    print("no is negative:")
else:
    print("zero:")
# Out:
# no is positive:

# %%
#2. Write a program to check whether a person can enter a movie theater. (Age must be 18 or above).

age = 23
if age>=18:
    print("you can enter a movie theater:")
else:
    print("you can't enter a movie theater:")
# Out:
# you can enter a movie theater:

# %%
#3. Write a program to check whether a number is divisible by 2.

num=10

if num%2==0:
    print("divisible by 2:")
else:
    print("not divisible by 2:")
# Out:
# divisible by 2:

# %%
#4. Write a program to compare two numbers and print the greater number.

num1=23
num2=56
if num1>num2:
    print("num1 is greater:")
else:
    print("num2 is greater:")
# Out:
# num2 is greater:

# %%
#5. Write a program to check whether a character is uppercase or lowercase.

ch = "DVITIYA"
if ch.isupper():
    print("uppercase:")
else:
    print("lowercase:")
# Out:
# uppercase:

# %%
#6.Write a program to check whether a year is a leap year or not.

year=2004
if year%4==0:
    print("Leap Year:")
else:
    print("Not")
# Out:
# Leap Year:

# %%
#7.Write a program to display:
# o "Morning" if time < 12
# o "Afternoon" if time between 12 and 5
# o "Evening" otherwise

time = int(input("Enter a time in hours(0-23):"))

if time<=12:
    print("Morning:")
elif time>=12 and time<=17:
    print("Afternoon:")
else:
    print("Evening:")
# Out:
# Enter a time in hours(0-23): 23
# Evening:

# %%
#8. Write a program to check whether a student passed with distinction.
# o 75+ → Distinction
# o 35–74 → Pass
# o Below 35 → Fail

marks = 78
if marks>75:
    print("Distinction:")
elif marks>75 and marks<30:
    print("Pass:")
else:
    print("Fail:")
# Out:
# Distinction:

# %%
#9. Write a program to find the largest among three numbers.

num1 = 23
num2 = 45
num3 = 67

if num1>num2 and num1>num3:
    print("num1 is largest:")
elif num2>num3 and num2>num1:
    print("num2 is largest:")
else:
    print("num3 is largest:")
# Out:
# num3 is largest:

# %%
#10. Write a program to calculate electricity bill:
# o Units < 100 → ₹2/unit
# o 100–300 → ₹4/unit
# o Above 300 → ₹6/unit

units=int(input("Enter a electricity bill:"))

if units<100:
    print("rs.2/unit:")
elif units>100 and units<300:
    print("rs.4/unit:")
else:
    print("rs.6/unit:")
# Out:
# Enter a electricity bill: 500
# rs.6/unit:

# %%
#11. Write a program to check whether a triangle is:
# o Equilateral
# o Isosceles
# o Scalene

A=10
B=10
C=10

if A+B>C:
    print("Valid Triangle:")
    if A==B==C:
        print("Equilateral:")
    elif A==B and B==C or C==A:
        print("Isosceles:")
    else:
        print("Scalene:")
else:
    print("Not a valid traingle:")
# Out:
# Valid Triangle:
# Equilateral:

# %%
#12. Write a program to calculate bonus:
#o Salary > 50000 → 20% bonus
#  Salary between 30000–50000 → 10% bonus
# o Otherwise → 5% bonus 

salary = 50000
if salary>50000:
    print("20% bonus:")
elif salary>50000 and salary<30000:
    print("10% bonus:")
else:
    print("5% bonus:")
# Out:
# 5% bonus:

# %%
#13. Write a program to check login credentials using username and password.

username = str(input("Enter a username:"))
password = input("Enter a password:")

if username=="admin" and password==1234:
    print("Login Successfully:")
else:
    print("Login Failed:")
# Out:
# Enter a username: dvitiya
# Enter a password: 1234
# Login Failed:

# %%
#14. Write a program to check whether a number is:
# o Multiple of both 3 and 5
# o Multiple of only 3
# o Multiple of only 5
# o None

num = 59
if num%3==0 and num%5==0:
    print("Multiple of both 3 and 5:")
elif num%3==0:
    print("Multiple of 3:")
elif num%5==0:
    print("Multiple of 5:")
else:
    print("None:")
# Out:
# None:

# %%
#15.Write a program to find whether a person is:
# o Child (0–12)
# o Teenager (13–19)
# o Adult (20–59)
# o Senior Citizen (60+)

age = int(input("Enter age:"))
if 0<=age <=12:
    print("Child:")
elif 13<=age <=19:
    print("Teenager:")
elif 20<=age <=59:
    print("Adult:")
else:
    print("Senior Citizen:")
# Out:
# Enter age: 12
# Child:

# %%
#16.Write a program to calculate ticket price:
#o Age below 5 → Free
#o 5–18 → ₹100
#o Adults → ₹200
#o Senior citizens → ₹150

age = int(input("Enter ur age:"))

if age<5: 
    print("Free:")
elif 5<=age<=18:
    print(" Ticket price: 100")
elif 19<=age <=59:
    print("Ticket price: 200")
else:
    print("Ticket price:150")
# Out:
# Enter ur age: 2
# Free:

# %%
#17. Write a program to create a simple ATM system:
#o Check balance
#o Withdraw money
#o Deposit money
#o Invalid option message

balance = 20000
print("1.check balance:")
print("2.Withdraw money:")
print("3.Deposit money:")

choice = int(input("Enter a choice:"))

if choice == 1:
    print("check balance:")
elif choice == 2:
    print("Withdraw money:")
elif choice == 3:
    print("Deposit money:")
else:
    print("Invalid:")
# Out:
# 1.check balance:
# 2.Withdraw money:
# 3.Deposit money:
# Enter a choice: 7
# Invalid:

# %%
#18. Write a program to calculate income tax:
#o Income below ₹250000 → No tax
#o ₹250000–₹500000 → 5%
#o ₹500000–₹1000000 → 20%
#o Above ₹1000000 → 30%

cash = 400000
if cash<250000:
    print("No tax:")
elif cash>=250000 and cash<=500000:
    print("5% tax:", cash*0.05)
elif cash>500000 and cash<=1000000:
    print("20% tax:", cash*0.20)
else:
    print("30% tax:", cash*0.30)
# Out:
# 5% tax: 20000.0

# %%
#19. Write a program to determine the type of roots in a quadratic equation using discriminant.

A = float(input("Enter coefficient A:"))
B = float(input("Enter coefficient B:"))
C = float(input("Enter coefficient C:"))

D = B**2 - 4*A*C

if D>0:
    print("Roots are Real and Distinct")
elif D==0:
    print("Roots are Real and Equal")
else:
    print("Roots are Imaginary")
# Out:
# Enter coefficient A: 23
# Enter coefficient B: 34
# Enter coefficient C: 56
# Roots are Imaginary

# %%
#20.Write a program to check whether three angles can form a valid triangle.

A=10
B=10
C=10

if A+B>C:
    print("Valid Triangle:")
else:
    print("Not a valid traingle:")
# Out:
# Valid Triangle:

# %%
#21. Write a program to determine the season based on month number.

month = int(input("Enter month number (1-12): "))

if month in (12, 1, 2):
    print("Winter Season")
elif month in (3, 4, 5):
    print("Summer Season")
elif month in (6, 7, 8, 9):
    print("Rainy Season")
elif month in (10, 11):
    print("Autumn Season")
else:
    print("Invalid month number")
# Out:
# Enter month number (1-12):  5
# Summer Season

# %%
#22. Write a program for an online shopping discount system:
#o Purchase above ₹5000 → 30% discount
#o ₹2000–₹5000 → 20% discount
#o Below ₹2000 → 10% discount

payment=1000
if payment>5000:
    print("30% discount:", payment*0.30)
elif payment>=2000 and payment<=5000:
    print("20% discount:", payment*0.20)
else:
    print("10% discount:",payment*0.10)
# Out:
# 10% discount: 100.0

# %%
#23. Write a program to assign employee performance ratings:
#o 90+ → Excellent
#o 70–89 → Good
#o 50–69 → Average
#o Below 50 → Poor

score = 99

if score>=90:
    print("Excellent:")
elif score>=70 and score<=89:
    print("Good:")
elif score>=50 and score<=69:
    print("Average:")
else:
    print("Poor:")
# Out:
# Excellent:
